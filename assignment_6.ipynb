# %% [markdown]
# # Question 1
# OBJECT ORIENTED PROGRAMMING:
# Object-oriented programming is a programming paradigm based on the concept of "objects", which can contain data, in the form of fields, and code, in the form of procedures. A feature of objects is an object's procedures that can access and often modify the data fields of the object with which they are associated.
# There are 4 major principles that make an language Object Oriented. These are,
# 1. Encapsulation
# 2. Data Abstraction
# 3. Polymorphism
# 4. Inheritance
#
# # Question 2
# Benefits of OOPS
# 1. Object oriented system can easily be upgraded from small to large system
# 2. Code reude is possible
# 3. It provides principle of data hiding helps for security
# 4. It is easy to partition the work in a project based on objects.
# 5. Encapsulation, improved software maintainability.
#
# # Question 3
#
# 1. Function
# Function is block of code that is also called by its name. (independent)
# The function can have different parameters or may not have any at all. If any data (parameters) are passed, they are passed explicitly.
# It may or may not return any data.
# Function does not deal with Class and its instance concept
#
# 2. Method
# Method is called by its name, but it is associated to an object (dependent).
# A method is implicitly passed the object on which it is invoked.
# It may or may not return any data.
# A method can operate on the data (instance variables) that is contained by the corresponding class.
#
# # Question 4
# 1. Class :
#         Class is a model or blueprint(map) of anything. It may be defined as something that can be followed to create objects and instances. It is a code template for creating object having same behaviours.
#
# 2. Object:
#         Object is a collection of data and methods that act on those data and it follows all the requirements of the class to which it is belonged
#
# 3. Attributes:
#         The attributes are data members (class variables and instance variables) and methods, accessed via dot notation.
#
# 4. Behaviour:
#         The behavior of an object is defined by its methods, which are the functions and subroutines defined within the object class. Without class methods, a class would simply be a structure. Methods determine what type of functionality a class has, how it modifies its data, and its overall behavior.

# %%
# Question 5
class Car() :
    def __init__(self,make,model,year,SeatingCapacity,EngineCapacity) :
        self.make = make
        self.model = model
        self.year = year
        self.SeatingCapacity = SeatingCapacity
        self.EngineCapacity = EngineCapacity
        self.speed = 80
    def CarDescription(self) :
        print(f"Company of the car is {self.make}")
        print(f"Model of the car is {self.model}")
        print(f"Making year of the car is {self.year}")
        print(f"Seating Capacity of the car is {self.SeatingCapacity}")
        print(f"Engine Capacity of the car is {self.EngineCapacity}")
    def AppliedBrake(self) :
        print(f"{self.make} {self.model} has applied the brakes")
    def CarSpeed(self) :
        print(f"The speed of the car is {self.speed} Kmh")
     


car1 = Car("Toyota","XLI","2019","4","1400cc")
car2 = Car("Suzuki","Cultus","2017",4,"800cc")
car3 = Car("Honda","City","2019",4,"1500 cc")
car4 = Car("Suzuki","Swift","2019",4,"1200cc")
car5 = Car("Toyota","Corolla","2018",4,"1800cc")

print("********* Description of Car 1 *********")
print(car1.CarDescription())
print(car1.AppliedBrake())
print(car1.CarSpeed())

print("\n******** Description of Car 2 ********")
print(car2.CarDescription())
print(car2.AppliedBrake())
print(car2.CarSpeed())

print("\n********* Description of Car 3 ********")
print(car3.CarDescription())
print(car3.AppliedBrake())
print(car3.CarSpeed())

print("\n******** Description of Car 4 *********")
print(car4.CarDescription())
print(car4.AppliedBrake())
print(car4.CarSpeed())

print("\n********* Description of Car 5 *********")
print(car5.CarDescription())
print(car5.AppliedBrake())
print(car5.CarSpeed())
# Out:
# ********* Description of Car 1 *********
# Company of the car is Toyota
# Model of the car is XLI
# Making year of the car is 2019
# Seating Capacity of the car is 4
# Engine Capacity of the car is 1400cc
# None
# Toyota XLI has applied the brakes
# None
# The speed of the car is 80 Kmh
# None
#
# ******** Description of Car 2 ********
# Company of the car is Suzuki
# Model of the car is Cultus
# Making year of the car is 2017
# Seating Capacity of the car is 4
# Engine Capacity of the car is 800cc
# None
# Suzuki Cultus has applied the brakes
# None
# The speed of the car is 80 Kmh
# None
#
# ********* Description of Car 3 ********
# Company of the car is Honda
# Model of the car is City
# Making year of the car is 2019
# Seating Capacity of the car is 4
# Engine Capacity of the car is 1500 cc
# None
# Honda City has applied the brakes
# None
# The speed of the car is 80 Kmh
# None
#
# ******** Description of Car 4 *********
# Company of the car is Suzuki
# ...
